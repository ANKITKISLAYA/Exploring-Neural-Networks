# %% [markdown]
# ![convolution-schematic.gif](attachment:51e5e034-8279-42e1-b27c-0f24d8377ab7.gif)

# %% [markdown]
#  The structure of this network follows the classic structure of CNNs, which is a mix of convolutional layers and max pooling, followed by fully-connected layers.
#
# The code you'll be looking at is similar to what you saw in the segment on Deep Neural Network in TensorFlow in the previous lesson, except we restructured the architecture of this network as a CNN.

# %% [markdown]
# ### Dataset
# Here we're importing the MNIST dataset and performing batch, scale, and One-Hot encode the data.

# %%
def batches(batch_size, features, labels):
    """
    Create batches of features and labels
    :param batch_size: The batch size
    :param features: List of features
    :param labels: List of labels
    :return: Batches of (Features, Labels)
    """
    assert len(features) == len(labels)
    outout_batches = []
    
    sample_size = len(features)
    for start_i in range(0, sample_size, batch_size):
        end_i = start_i + batch_size
        batch = [features[start_i:end_i], labels[start_i:end_i]]
        outout_batches.append(batch)
        
    return outout_batches

# %%
import numpy as np

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from tensorflow import keras
from keras import backend as k




(x_train, y_train) , (x_test, y_test) = keras.datasets.mnist.load_data()


# Flattening the matrix for training set and test set
# x_train = x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2])
# x_test = x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2])
x_train = x_train.astype('float32')
x_test = x_test.astype('float32') 


# one hot encoding for the lables in train and test
temp_train = np.zeros([y_train.shape[0],y_train.max()+1],dtype = np.float32)
temp_train[np.arange(y_train.shape[0]),y_train] = 1
y_train = temp_train

temp_test = np.zeros([y_test.shape[0],y_test.max()+1],dtype = np.float32)
temp_test[np.arange(y_test.shape[0]),y_test] = 1
y_test = temp_test

# Applying Channels in the image
img_rows, img_cols=28, 28

if k.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    inpx = (1, img_rows, img_cols)

else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    inpx = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255


# Parameters
learning_rate = 0.00001
epochs = 10
batch_size = 128

# Number of samples to calculate validation and accuracy
# Decrease this if you're running out of memory to calculate accuracy
test_valid_size = 256

# Network Parameters
n_classes = 10  # MNIST total classes (0-9 digits)
dropout = 0.75  # Dropout, probability to keep units
# Out:
# WARNING:tensorflow:From C:\Users\akislaya\Anaconda3\envs\IntroToTensorFlow\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)
# (60000, 10)
# (10000, 10)

# %% [markdown]
# ### Weights and Biases
#
# weight = tf.Variable(tf.truncated_normal(
#     [filter_size_height, filter_size_width, color_channels, k_output]))
#
# bias = tf.Variable(tf.zeros(k_output))

# %%
# Store layers weight & bias
weights = {
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])), #flattened output gives 7*7*64 and 1024 is number 
                                                          # of neurons of 1st layer of FC network  
    'out': tf.Variable(tf.random_normal([1024, n_classes]))}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))}

# %%
biases['bd1']
# Out:
# <tf.Variable 'Variable_14:0' shape=(1024,) dtype=float32_ref>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The above is an example of a convolution with a 3x3 filter and a stride of 1 being applied to data with a range of 0 to 1. The convolution for each 3x3 section is calculated against the weight, [[1, 0, 1], [0, 1, 0], [1, 0, 1]], then a bias is added to create the convolved feature on the right. In this case, the bias is zero. In TensorFlow, this is all done using tf.nn.conv2d() and tf.nn.bias_add().

# %% [markdown]
# TensorFlow uses the following equation for 'SAME' vs 'VALID'
#
# SAME Padding, the output height and width are computed as:
#
# out_height = ceil(float(in_height) / float(strides[1]))
#
# out_width = ceil(float(in_width) / float(strides[2]))
#
# VALID Padding, the output height and width are computed as:
#
# out_height = ceil(float(in_height - filter_height + 1) / float(strides[1]))
#
# out_width = ceil(float(in_width - filter_width + 1) / float(strides[2]))

# %%
def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

# %% [markdown]
# The tf.nn.conv2d() function computes the convolution against weight W as shown above.
#
# In TensorFlow, strides is an array of 4 elements; the first element in this array indicates the stride for batch and last element indicates stride for features. It's good practice to remove the batches or features you want to skip from the data set rather than use a stride to skip them. You can always set the first and last element to 1 in strides in order to use all batches and features.
#
# The middle two elements are the strides for height and width respectively. I've mentioned stride as one number because you usually have a square stride where height = width. When someone says they are using a stride of 3, they usually mean tf.nn.conv2d(x, W, strides=[1, 3, 3, 1]).
#
# To make things easier, the code is using tf.nn.bias_add() to add the bias. Using tf.add() doesn't work when the tensors aren't the same shape.

# %% [markdown]
# ### Max Pooling

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def maxpool2d(x, k=2):
    return tf.nn.max_pool(
        x,
        ksize=[1, k, k, 1],
        strides=[1, k, k, 1],
        padding='SAME')

# %% [markdown]
# The tf.nn.max_pool() function does exactly what you would expect, it performs max pooling with the ksize parameter as the size of the filter.

# %% [markdown]
# ### Model
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In the code below, we're creating 3 layers alternating between convolutions and max pooling followed by a fully connected and output layer. The transformation of each layer to new dimensions are shown in the comments. For example, the first layer shapes the images from 28x28x1 to 28x28x32 in the convolution step. Then next step applies max pooling, turning each sample into 14x14x32. All the layers are applied from conv1 to output, producing 10 class predictions.

# %%
def conv_net(x, weights, biases, dropout):
    # Layer 1 - 28*28*1 to 14*14*32 since for pooling the stride will be 2 
    # output of pooling for same padding is out_height = ceil(float(in_height) / float(strides[1]))
    # ceil((28)/2) = 14
    # Shape of weights['wc1'] is (5, 5, 1, 32) and biases['bc1'] is (32,)
    conv1 = conv2d(x, weights['wc1'], biases['bc1']) # Output Shape here is 28x28x32
    conv1 = maxpool2d(conv1, k=2) # Output Shape here is 14x14x32

    # Layer 2 - 14*14*32 to 7*7*64
    # Shape of weights['wc2'] is (5, 5, 32, 64) and biases['bc2'] is (64,)
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2']) # Output Shape here is 14x14x64
    conv2 = maxpool2d(conv2, k=2) # Output Shape here is 7x7x64

    # Fully connected layer - 7*7*64 = 3136 to 1024 
    # shape of  weights['wd1'] is (3136, 1024) and shape of biases['bd1'] is (1024,) 
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]]) # Flattening the output 7x7x64
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output Layer - class prediction - 1024 to 10
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# tf Graph input
x = tf.placeholder(tf.float32, [None, 28, 28, 1])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32)

# Model
logits = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(\
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)\
    .minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf. global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    for epoch in range(epochs):
        batch = 0
        for batch_x, batch_y in batches(batch_size, x_train, y_train):
            batch += 1
            sess.run(optimizer, feed_dict={
                x: batch_x,
                y: batch_y,
                keep_prob: dropout})

            # Calculate batch loss and accuracy
            loss = sess.run(cost, feed_dict={
                x: batch_x,
                y: batch_y,
                keep_prob: 1.})
            valid_acc = sess.run(accuracy, feed_dict={
                x: x_test,
                y: y_test,
                keep_prob: 1.})
            
        # Print status for every 10 epochs
       # if epoch % 10 == 0:
            print('Epoch {:>2}, Batch {:>3} -'
                  'Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                epoch + 1,
                batch + 1,
                loss,
                valid_acc))

    # Calculate Test Accuracy
    test_acc = sess.run(accuracy, feed_dict={
        x: x_test,
        y: y_test,
        keep_prob: 1.})
    print('Testing Accuracy: {}'.format(test_acc))
# Out:
# WARNING:tensorflow:From C:\Users\akislaya\Anaconda3\envs\IntroToTensorFlow\lib\site-packages\tensorflow\python\util\dispatch.py:1176: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\akislaya\Anaconda3\envs\IntroToTensorFlow\lib\site-packages\tensorflow\python\util\dispatch.py:1176: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Epoch  1, Batch   2 -Loss: 55224.2461 Validation Accuracy: 0.092400
# Epoch  1, Batch   3 -Loss: 43446.0703 Validation Accuracy: 0.105100
# Epoch  1, Batch   4 -Loss: 39467.3633 Validation Accuracy: 0.105600
# Epoch  1, Batch   5 -Loss: 29214.5820 Validation Accuracy: 0.118400
# Epoch  1, Batch   6 -Loss: 27932.2363 Validation Accuracy: 0.110300
# Epoch  1, Batch   7 -Loss: 27398.3633 Validation Accuracy: 0.109500
# Epoch  1, Batch   8 -Loss: 24542.7793 Validation Accuracy: 0.115100
# Epoch  1, Batch   9 -Loss: 26589.3477 Validation Accuracy: 0.116900
# Epoch  1, Batch  10 -Loss: 22589.0020 Validation Accuracy: 0.143300
# Epoch  1, Batch  11 -Loss: 23184.1836 Validation Accuracy: 0.135000
# Epoch  1, Batch  12 -Loss: 20088.2441 Validation Accuracy: 0.166200
# Epoch  1, Batch  13 -Loss: 20656.0078 Validation Accuracy: 0.175700
# Epoch  1, Batch  14 -Loss: 21090.2012 Validation Accuracy: 0.186700
# Epoch  1, Batch  15 -Loss: 17205.7578 Validation Accuracy: 0.212400
# Epoch  1, Batch  16 -Loss: 17672.3066 Validation Accuracy: 0.228000
# Epoch  1, Batch  17 -Loss: 18806.1914 Validation Accuracy: 0.210700
# Epoch  1, Batch  18 -Loss: 17532.7383 Validation Accuracy: 0.210400
# Epoch  1, Batch  19 -Loss: 18931.8965 Validation Accuracy: 0.201600
# Epoch  1, Batch  20 -Loss: 18333.8906 Validation Accuracy: 0.212500
# Epoch  1, Batch  21 -Loss: 17741.1406 Validation Accuracy: 0.226700
# Epoch  1, Batch  22 -Loss: 16913.0840 Validation Accuracy: 0.248800
# Epoch  1, Batch  23 -Loss: 14785.5430 Validation Accuracy: 0.254700
# Epoch  1, Batch  24 -Loss: 15378.7490 Validation Accuracy: 0.263000
# Epoch  1, Batch  25 -Loss: 14715.2383 Validation Accuracy: 0.271900
# Epoch  1, Batch  26 -Loss: 13493.7969 Validation Accuracy: 0.275100
# Epoch  1, Batch  27 -Loss: 13011.4316 Validation Accuracy: 0.268700
# Epoch  1, Batch  28 -Loss: 10733.9570 Validation Accuracy: 0.276800
# Epoch  1, Batch  29 -Loss: 10955.3125 Validation Accuracy: 0.286600
# Epoch  1, Batch  30 -Loss: 12077.0898 Validation Accuracy: 0.294300
# Epoch  1, Batch  31 -Loss: 13515.1875 Validation Accuracy: 0.308000
# Epoch  1, Batch  32 -Loss: 11456.6221 Validation Accuracy: 0.313000
# Epoch  1, Batch  33 -Loss: 13584.7637 Validation Accuracy: 0.326300
# Epoch  1, Batch  34 -Loss: 12229.0039 Validation Accuracy: 0.329600
# Epoch  1, Batch  35 -Loss: 11859.7275 Validation Accuracy: 0.329400
# Epoch  1, Batch  36 -Loss: 14531.5869 Validation Accuracy: 0.337700
# Epoch  1, Batch  37 -Loss: 10374.6221 Validation Accuracy: 0.343900
# Epoch  1, Batch  38 -Loss: 11110.1348 Validation Accuracy: 0.354900
# Epoch  1, Batch  39 -Loss: 11883.1406 Validation Accuracy: 0.338900
# Epoch  1, Batch  40 -Loss: 10055.9062 Validation Accuracy: 0.347700
# Epoch  1, Batch  41 -Loss: 10205.9102 Validation Accuracy: 0.344200
# Epoch  1, Batch  42 -Loss:  9857.2109 Validation Accuracy: 0.352600
# Epoch  1, Batch  43 -Loss:  6849.3628 Validation Accuracy: 0.362100
# Epoch  1, Batch  44 -Loss:  7622.8545 Validation Accuracy: 0.371800
# Epoch  1, Batch  45 -Loss:  8239.1680 Validation Accuracy: 0.380700
# Epoch  1, Batch  46 -Loss: 10430.6016 Validation Accuracy: 0.394200
# Epoch  1, Batch  47 -Loss:  9831.8613 Validation Accuracy: 0.396200
# Epoch  1, Batch  48 -Loss:  8165.3315 Validation Accuracy: 0.408200
# Epoch  1, Batch  49 -Loss:  7638.1543 Validation Accuracy: 0.410000
# Epoch  1, Batch  50 -Loss:  7350.8164 Validation Accuracy: 0.412000
# Epoch  1, Batch  51 -Loss:  8194.9590 Validation Accuracy: 0.416100
# Epoch  1, Batch  52 -Loss:  9214.6992 Validation Accuracy: 0.419400
# Epoch  1, Batch  53 -Loss:  7340.4492 Validation Accuracy: 0.425800
# Epoch  1, Batch  54 -Loss:  8700.6514 Validation Accuracy: 0.429100
# Epoch  1, Batch  55 -Loss:  9433.3594 Validation Accuracy: 0.426300
# Epoch  1, Batch  56 -Loss:  6697.2021 Validation Accuracy: 0.428900
# Epoch  1, Batch  57 -Loss:  5985.7676 Validation Accuracy: 0.430500
# Epoch  1, Batch  58 -Loss:  9959.3047 Validation Accuracy: 0.441800
# Epoch  1, Batch  59 -Loss:  7416.3740 Validation Accuracy: 0.444800
# Epoch  1, Batch  60 -Loss:  8726.3457 Validation Accuracy: 0.442700
# Epoch  1, Batch  61 -Loss:  7406.2471 Validation Accuracy: 0.448400
# Epoch  1, Batch  62 -Loss:  8669.7695 Validation Accuracy: 0.450800
# Epoch  1, Batch  63 -Loss:  6668.4497 Validation Accuracy: 0.454000
# Epoch  1, Batch  64 -Loss:  6978.3906 Validation Accuracy: 0.462100
# Epoch  1, Batch  65 -Loss:  6572.8760 Validation Accuracy: 0.469000
# Epoch  1, Batch  66 -Loss:  6352.3838 Validation Accuracy: 0.467900
# Epoch  1, Batch  67 -Loss:  7105.6919 Validation Accuracy: 0.473600
# Epoch  1, Batch  68 -Loss:  6375.2437 Validation Accuracy: 0.475300
# Epoch  1, Batch  69 -Loss:  7592.5283 Validation Accuracy: 0.469500
# Epoch  1, Batch  70 -Loss:  7535.8721 Validation Accuracy: 0.479600
# Epoch  1, Batch  71 -Loss:  8154.6406 Validation Accuracy: 0.474600
# Epoch  1, Batch  72 -Loss:  6231.3818 Validation Accuracy: 0.482700
# Epoch  1, Batch  73 -Loss:  5102.2979 Validation Accuracy: 0.486400
# Epoch  1, Batch  74 -Loss:  5496.6934 Validation Accuracy: 0.486700
# Epoch  1, Batch  75 -Loss:  6088.4897 Validation Accuracy: 0.484300
# Epoch  1, Batch  76 -Loss:  5856.5439 Validation Accuracy: 0.490600
# Epoch  1, Batch  77 -Loss:  6105.8848 Validation Accuracy: 0.489800
# Epoch  1, Batch  78 -Loss:  5067.0942 Validation Accuracy: 0.497600
# Epoch  1, Batch  79 -Loss:  4339.4141 Validation Accuracy: 0.503200
# Epoch  1, Batch  80 -Loss:  4711.3804 Validation Accuracy: 0.506200
# Epoch  1, Batch  81 -Loss:  5477.5288 Validation Accuracy: 0.503300
# Epoch  1, Batch  82 -Loss:  6260.1172 Validation Accuracy: 0.505100
# Epoch  1, Batch  83 -Loss:  4893.7759 Validation Accuracy: 0.513100
# Epoch  1, Batch  84 -Loss:  4294.0020 Validation Accuracy: 0.518900
# Epoch  1, Batch  85 -Loss:  4191.1421 Validation Accuracy: 0.515500
# Epoch  1, Batch  86 -Loss:  5426.7246 Validation Accuracy: 0.522600
# Epoch  1, Batch  87 -Loss:  5205.1240 Validation Accuracy: 0.520700
# Epoch  1, Batch  88 -Loss:  4114.6738 Validation Accuracy: 0.521800
# Epoch  1, Batch  89 -Loss:  5324.4863 Validation Accuracy: 0.526800
# Epoch  1, Batch  90 -Loss:  5940.5229 Validation Accuracy: 0.531000
# Epoch  1, Batch  91 -Loss:  4780.5396 Validation Accuracy: 0.534200
# Epoch  1, Batch  92 -Loss:  4720.3828 Validation Accuracy: 0.534800
# Epoch  1, Batch  93 -Loss:  5942.0908 Validation Accuracy: 0.538800
# Epoch  1, Batch  94 -Loss:  5150.7979 Validation Accuracy: 0.539700
# Epoch  1, Batch  95 -Loss:  5564.4385 Validation Accuracy: 0.540900
# Epoch  1, Batch  96 -Loss:  4638.6118 Validation Accuracy: 0.539300
# Epoch  1, Batch  97 -Loss:  3618.4331 Validation Accuracy: 0.543900
# Epoch  1, Batch  98 -Loss:  5147.7939 Validation Accuracy: 0.545400
# Epoch  1, Batch  99 -Loss:  5842.9170 Validation Accuracy: 0.546800
# Epoch  1, Batch 100 -Loss:  5778.9712 Validation Accuracy: 0.548000
# Epoch  1, Batch 101 -Loss:  4942.8091 Validation Accuracy: 0.550000
# Epoch  1, Batch 102 -Loss:  4956.7544 Validation Accuracy: 0.553600
# Epoch  1, Batch 103 -Loss:  6851.1875 Validation Accuracy: 0.557500
# Epoch  1, Batch 104 -Loss:  5420.9033 Validation Accuracy: 0.558900
# Epoch  1, Batch 105 -Loss:  5184.0908 Validation Accuracy: 0.563700
# Epoch  1, Batch 106 -Loss:  4459.5581 Validation Accuracy: 0.564800
# Epoch  1, Batch 107 -Loss:  4694.4517 Validation Accuracy: 0.566200
# Epoch  1, Batch 108 -Loss:  4258.9502 Validation Accuracy: 0.570300
# Epoch  1, Batch 109 -Loss:  5364.1621 Validation Accuracy: 0.573500
# Epoch  1, Batch 110 -Loss:  5396.2520 Validation Accuracy: 0.574500
# Epoch  1, Batch 111 -Loss:  5347.9131 Validation Accuracy: 0.571900
# Epoch  1, Batch 112 -Loss:  5198.4756 Validation Accuracy: 0.573900
# Epoch  1, Batch 113 -Loss:  5665.9214 Validation Accuracy: 0.571600
# Epoch  1, Batch 114 -Loss:  5662.6514 Validation Accuracy: 0.577300
# Epoch  1, Batch 115 -Loss:  5921.9805 Validation Accuracy: 0.576100
# Epoch  1, Batch 116 -Loss:  7183.4824 Validation Accuracy: 0.572300
# Epoch  1, Batch 117 -Loss:  6416.1182 Validation Accuracy: 0.576800
# Epoch  1, Batch 118 -Loss:  3725.4014 Validation Accuracy: 0.578900
# Epoch  1, Batch 119 -Loss:  4378.1768 Validation Accuracy: 0.583200
# Epoch  1, Batch 120 -Loss:  5240.7544 Validation Accuracy: 0.584100
# Epoch  1, Batch 121 -Loss:  3736.2703 Validation Accuracy: 0.583900
# Epoch  1, Batch 122 -Loss:  5211.5737 Validation Accuracy: 0.584900
# Epoch  1, Batch 123 -Loss:  3945.6816 Validation Accuracy: 0.590900
# Epoch  1, Batch 124 -Loss:  4724.1602 Validation Accuracy: 0.593900
# Epoch  1, Batch 125 -Loss:  6322.9971 Validation Accuracy: 0.593600
# Epoch  1, Batch 126 -Loss:  4745.6016 Validation Accuracy: 0.594600
# Epoch  1, Batch 127 -Loss:  4369.6201 Validation Accuracy: 0.595700
# Epoch  1, Batch 128 -Loss:  3911.6067 Validation Accuracy: 0.594800
# Epoch  1, Batch 129 -Loss:  4365.0532 Validation Accuracy: 0.595900
# Epoch  1, Batch 130 -Loss:  4044.3569 Validation Accuracy: 0.598000
# Epoch  1, Batch 131 -Loss:  2868.1577 Validation Accuracy: 0.599500
# Epoch  1, Batch 132 -Loss:  4968.3257 Validation Accuracy: 0.601200
# Epoch  1, Batch 133 -Loss:  4350.3149 Validation Accuracy: 0.600900
# Epoch  1, Batch 134 -Loss:  4965.7388 Validation Accuracy: 0.601400
# Epoch  1, Batch 135 -Loss:  3906.2039 Validation Accuracy: 0.603200
# Epoch  1, Batch 136 -Loss:  4531.6089 Validation Accuracy: 0.605400
# Epoch  1, Batch 137 -Loss:  3358.9756 Validation Accuracy: 0.604700
# Epoch  1, Batch 138 -Loss:  3762.5334 Validation Accuracy: 0.605000
# Epoch  1, Batch 139 -Loss:  4295.4912 Validation Accuracy: 0.605400
# Epoch  1, Batch 140 -Loss:  4522.6416 Validation Accuracy: 0.604600
# Epoch  1, Batch 141 -Loss:  5207.4146 Validation Accuracy: 0.607800
# Epoch  1, Batch 142 -Loss:  2347.4978 Validation Accuracy: 0.611200
# Epoch  1, Batch 143 -Loss:  3880.3853 Validation Accuracy: 0.613400
# Epoch  1, Batch 144 -Loss:  3794.3325 Validation Accuracy: 0.613100
# Epoch  1, Batch 145 -Loss:  3464.0647 Validation Accuracy: 0.619500
# Epoch  1, Batch 146 -Loss:  2997.5264 Validation Accuracy: 0.620100
# Epoch  1, Batch 147 -Loss:  3385.0054 Validation Accuracy: 0.617400
# Epoch  1, Batch 148 -Loss:  2631.9736 Validation Accuracy: 0.618900
# Epoch  1, Batch 149 -Loss:  2368.9927 Validation Accuracy: 0.620800
# Epoch  1, Batch 150 -Loss:  3254.3857 Validation Accuracy: 0.623500
# Epoch  1, Batch 151 -Loss:  4074.1313 Validation Accuracy: 0.623600
# Epoch  1, Batch 152 -Loss:  2608.2551 Validation Accuracy: 0.622900
# Epoch  1, Batch 153 -Loss:  3606.2200 Validation Accuracy: 0.625500
# Epoch  1, Batch 154 -Loss:  3506.6780 Validation Accuracy: 0.624200
# Epoch  1, Batch 155 -Loss:  3429.2627 Validation Accuracy: 0.626200
# Epoch  1, Batch 156 -Loss:  3865.4563 Validation Accuracy: 0.625500
# Epoch  1, Batch 157 -Loss:  4725.4023 Validation Accuracy: 0.622500
# Epoch  1, Batch 158 -Loss:  4620.2686 Validation Accuracy: 0.621900
# Epoch  1, Batch 159 -Loss:  3979.4912 Validation Accuracy: 0.623900
# Epoch  1, Batch 160 -Loss:  3693.3792 Validation Accuracy: 0.627100
# Epoch  1, Batch 161 -Loss:  3419.0806 Validation Accuracy: 0.631600
# Epoch  1, Batch 162 -Loss:  3403.3142 Validation Accuracy: 0.633900
# Epoch  1, Batch 163 -Loss:  2496.2441 Validation Accuracy: 0.636300
# Epoch  1, Batch 164 -Loss:  2890.1895 Validation Accuracy: 0.640200
# Epoch  1, Batch 165 -Loss:  3503.5557 Validation Accuracy: 0.637700
# Epoch  1, Batch 166 -Loss:  3303.2788 Validation Accuracy: 0.638800
# Epoch  1, Batch 167 -Loss:  2472.8257 Validation Accuracy: 0.640100
# Epoch  1, Batch 168 -Loss:  3697.2612 Validation Accuracy: 0.640400
# Epoch  1, Batch 169 -Loss:  4036.3926 Validation Accuracy: 0.642300
# Epoch  1, Batch 170 -Loss:  3244.4854 Validation Accuracy: 0.640900
# Epoch  1, Batch 171 -Loss:  3627.6802 Validation Accuracy: 0.644700
# Epoch  1, Batch 172 -Loss:  2601.1611 Validation Accuracy: 0.646200
# Epoch  1, Batch 173 -Loss:  2268.3872 Validation Accuracy: 0.646900
# Epoch  1, Batch 174 -Loss:  4094.0037 Validation Accuracy: 0.648100
# Epoch  1, Batch 175 -Loss:  5035.7803 Validation Accuracy: 0.647600
# Epoch  1, Batch 176 -Loss:  2325.4194 Validation Accuracy: 0.648700
# Epoch  1, Batch 177 -Loss:  3460.2217 Validation Accuracy: 0.650100
# Epoch  1, Batch 178 -Loss:  4648.2871 Validation Accuracy: 0.650300
# Epoch  1, Batch 179 -Loss:  3456.1443 Validation Accuracy: 0.647100
# Epoch  1, Batch 180 -Loss:  3169.3943 Validation Accuracy: 0.647900
# Epoch  1, Batch 181 -Loss:  2509.1880 Validation Accuracy: 0.650200
# Epoch  1, Batch 182 -Loss:  2626.4983 Validation Accuracy: 0.651900
# Epoch  1, Batch 183 -Loss:  2246.3928 Validation Accuracy: 0.649500
# Epoch  1, Batch 184 -Loss:  2686.8213 Validation Accuracy: 0.650500
# Epoch  1, Batch 185 -Loss:  2763.1831 Validation Accuracy: 0.652200
# Epoch  1, Batch 186 -Loss:  2884.4624 Validation Accuracy: 0.655300
# Epoch  1, Batch 187 -Loss:  3534.1248 Validation Accuracy: 0.656200
# Epoch  1, Batch 188 -Loss:  2558.5811 Validation Accuracy: 0.654900
# Epoch  1, Batch 189 -Loss:  3348.6328 Validation Accuracy: 0.656800
# Epoch  1, Batch 190 -Loss:  2577.3691 Validation Accuracy: 0.658200
# Epoch  1, Batch 191 -Loss:  4201.8281 Validation Accuracy: 0.658700
# Epoch  1, Batch 192 -Loss:  1786.4817 Validation Accuracy: 0.659600
# Epoch  1, Batch 193 -Loss:  4145.8643 Validation Accuracy: 0.661100
# Epoch  1, Batch 194 -Loss:  3593.2139 Validation Accuracy: 0.664700
# Epoch  1, Batch 195 -Loss:  4029.9546 Validation Accuracy: 0.662400
# Epoch  1, Batch 196 -Loss:  2751.9873 Validation Accuracy: 0.660700
# Epoch  1, Batch 197 -Loss:  1939.7725 Validation Accuracy: 0.662100
# Epoch  1, Batch 198 -Loss:  2345.9099 Validation Accuracy: 0.661700
# Epoch  1, Batch 199 -Loss:  2889.2466 Validation Accuracy: 0.662300
# Epoch  1, Batch 200 -Loss:  2437.7703 Validation Accuracy: 0.664200
# Epoch  1, Batch 201 -Loss:  1997.8164 Validation Accuracy: 0.662500
# Epoch  1, Batch 202 -Loss:  2777.8213 Validation Accuracy: 0.666400
# Epoch  1, Batch 203 -Loss:  3032.4355 Validation Accuracy: 0.668500
# Epoch  1, Batch 204 -Loss:  3596.2783 Validation Accuracy: 0.669200
# Epoch  1, Batch 205 -Loss:  3476.7954 Validation Accuracy: 0.667100
# Epoch  1, Batch 206 -Loss:  2873.4121 Validation Accuracy: 0.667500
# Epoch  1, Batch 207 -Loss:  1889.4897 Validation Accuracy: 0.670700
# Epoch  1, Batch 208 -Loss:  2754.4614 Validation Accuracy: 0.672600
# Epoch  1, Batch 209 -Loss:  3309.1541 Validation Accuracy: 0.672300
# Epoch  1, Batch 210 -Loss:  3528.3362 Validation Accuracy: 0.672600
# Epoch  1, Batch 211 -Loss:  2963.4604 Validation Accuracy: 0.672200
# Epoch  1, Batch 212 -Loss:  2557.0269 Validation Accuracy: 0.674300
# Epoch  1, Batch 213 -Loss:  2913.1309 Validation Accuracy: 0.674200
# Epoch  1, Batch 214 -Loss:  3093.7583 Validation Accuracy: 0.677500
# Epoch  1, Batch 215 -Loss:  2565.9238 Validation Accuracy: 0.677400
# Epoch  1, Batch 216 -Loss:  3431.5879 Validation Accuracy: 0.676800
# Epoch  1, Batch 217 -Loss:  2307.2014 Validation Accuracy: 0.677100
# Epoch  1, Batch 218 -Loss:  1952.1532 Validation Accuracy: 0.678900
# Epoch  1, Batch 219 -Loss:  2677.0042 Validation Accuracy: 0.680700
# Epoch  1, Batch 220 -Loss:  1715.8918 Validation Accuracy: 0.678600
# Epoch  1, Batch 221 -Loss:  2132.3208 Validation Accuracy: 0.680600
# Epoch  1, Batch 222 -Loss:  2724.2166 Validation Accuracy: 0.680800
# Epoch  1, Batch 223 -Loss:  2991.2585 Validation Accuracy: 0.680100
# Epoch  1, Batch 224 -Loss:  2674.6553 Validation Accuracy: 0.679600
# Epoch  1, Batch 225 -Loss:  3513.0854 Validation Accuracy: 0.678900
# Epoch  1, Batch 226 -Loss:  2612.4609 Validation Accuracy: 0.680600
# Epoch  1, Batch 227 -Loss:  3107.6960 Validation Accuracy: 0.682300
# Epoch  1, Batch 228 -Loss:  2173.6436 Validation Accuracy: 0.683200
# Epoch  1, Batch 229 -Loss:  3070.6216 Validation Accuracy: 0.681500
# Epoch  1, Batch 230 -Loss:  2619.4160 Validation Accuracy: 0.681900
# Epoch  1, Batch 231 -Loss:  2234.5486 Validation Accuracy: 0.681300
# Epoch  1, Batch 232 -Loss:  2035.5059 Validation Accuracy: 0.683500
# Epoch  1, Batch 233 -Loss:  2218.3206 Validation Accuracy: 0.686000
# Epoch  1, Batch 234 -Loss:  3282.0562 Validation Accuracy: 0.685900
# Epoch  1, Batch 235 -Loss:  3284.0203 Validation Accuracy: 0.687100
# Epoch  1, Batch 236 -Loss:  2306.4587 Validation Accuracy: 0.686000
# Epoch  1, Batch 237 -Loss:  3200.9458 Validation Accuracy: 0.687000
# Epoch  1, Batch 238 -Loss:  2017.7974 Validation Accuracy: 0.684400
# Epoch  1, Batch 239 -Loss:  2611.8569 Validation Accuracy: 0.685200
# Epoch  1, Batch 240 -Loss:  2889.2761 Validation Accuracy: 0.685700
# Epoch  1, Batch 241 -Loss:  2597.7373 Validation Accuracy: 0.687800
# Epoch  1, Batch 242 -Loss:  3056.3928 Validation Accuracy: 0.689500
# Epoch  1, Batch 243 -Loss:  2838.4646 Validation Accuracy: 0.689300
# Epoch  1, Batch 244 -Loss:  3868.8953 Validation Accuracy: 0.687600
# Epoch  1, Batch 245 -Loss:  2417.5574 Validation Accuracy: 0.689400
# Epoch  1, Batch 246 -Loss:  3032.8789 Validation Accuracy: 0.687200
# Epoch  1, Batch 247 -Loss:  2212.8552 Validation Accuracy: 0.689200
# Epoch  1, Batch 248 -Loss:  2291.6821 Validation Accuracy: 0.692200
# Epoch  1, Batch 249 -Loss:  2749.1851 Validation Accuracy: 0.692200
# Epoch  1, Batch 250 -Loss:  2820.6753 Validation Accuracy: 0.690700
# Epoch  1, Batch 251 -Loss:  2430.1699 Validation Accuracy: 0.693000
# Epoch  1, Batch 252 -Loss:  2887.8201 Validation Accuracy: 0.691900
# Epoch  1, Batch 253 -Loss:  3061.7141 Validation Accuracy: 0.689500
# Epoch  1, Batch 254 -Loss:  3094.8335 Validation Accuracy: 0.686500
# Epoch  1, Batch 255 -Loss:  3242.0493 Validation Accuracy: 0.687300
# Epoch  1, Batch 256 -Loss:  2226.7612 Validation Accuracy: 0.689300
# Epoch  1, Batch 257 -Loss:  1828.6772 Validation Accuracy: 0.688600
# Epoch  1, Batch 258 -Loss:  2313.6121 Validation Accuracy: 0.689300
# Epoch  1, Batch 259 -Loss:  2373.4880 Validation Accuracy: 0.693400
# Epoch  1, Batch 260 -Loss:  2443.6265 Validation Accuracy: 0.695100
# Epoch  1, Batch 261 -Loss:  3107.6426 Validation Accuracy: 0.695400
# Epoch  1, Batch 262 -Loss:  2208.2158 Validation Accuracy: 0.698000
# Epoch  1, Batch 263 -Loss:  1859.6195 Validation Accuracy: 0.697600
# Epoch  1, Batch 264 -Loss:  2143.1892 Validation Accuracy: 0.698300
# Epoch  1, Batch 265 -Loss:  2317.0122 Validation Accuracy: 0.700300
# Epoch  1, Batch 266 -Loss:  1840.3120 Validation Accuracy: 0.701600
# Epoch  1, Batch 267 -Loss:  1251.1182 Validation Accuracy: 0.700500
# Epoch  1, Batch 268 -Loss:  2259.2617 Validation Accuracy: 0.700900
# Epoch  1, Batch 269 -Loss:  1578.5701 Validation Accuracy: 0.701300
# Epoch  1, Batch 270 -Loss:  2776.6675 Validation Accuracy: 0.701500
# Epoch  1, Batch 271 -Loss:  2608.3440 Validation Accuracy: 0.703800
# Epoch  1, Batch 272 -Loss:  2420.7856 Validation Accuracy: 0.704100
# Epoch  1, Batch 273 -Loss:  2285.7874 Validation Accuracy: 0.704500
# Epoch  1, Batch 274 -Loss:  2836.0640 Validation Accuracy: 0.703400
# Epoch  1, Batch 275 -Loss:  1501.5195 Validation Accuracy: 0.704700
# Epoch  1, Batch 276 -Loss:  1926.0791 Validation Accuracy: 0.705300
# Epoch  1, Batch 277 -Loss:  1951.6877 Validation Accuracy: 0.705300
# Epoch  1, Batch 278 -Loss:  2067.9917 Validation Accuracy: 0.706400
# Epoch  1, Batch 279 -Loss:  1740.9727 Validation Accuracy: 0.707400
# Epoch  1, Batch 280 -Loss:  1916.1901 Validation Accuracy: 0.708400
# Epoch  1, Batch 281 -Loss:  2414.8606 Validation Accuracy: 0.706500
# Epoch  1, Batch 282 -Loss:  2506.4199 Validation Accuracy: 0.709100
# Epoch  1, Batch 283 -Loss:  2567.5276 Validation Accuracy: 0.710700
# Epoch  1, Batch 284 -Loss:  1969.4878 Validation Accuracy: 0.710000
# Epoch  1, Batch 285 -Loss:  1556.5933 Validation Accuracy: 0.707500
# Epoch  1, Batch 286 -Loss:  2616.3008 Validation Accuracy: 0.708400
# Epoch  1, Batch 287 -Loss:  2093.8696 Validation Accuracy: 0.707900
# Epoch  1, Batch 288 -Loss:  1053.3903 Validation Accuracy: 0.708200
# Epoch  1, Batch 289 -Loss:  2635.9014 Validation Accuracy: 0.708200
# Epoch  1, Batch 290 -Loss:  1588.6215 Validation Accuracy: 0.708200
# Epoch  1, Batch 291 -Loss:  2268.2119 Validation Accuracy: 0.708400
# Epoch  1, Batch 292 -Loss:  2475.0193 Validation Accuracy: 0.709200
# Epoch  1, Batch 293 -Loss:  3191.8435 Validation Accuracy: 0.704900
# Epoch  1, Batch 294 -Loss:  2845.7385 Validation Accuracy: 0.704000
# Epoch  1, Batch 295 -Loss:  2765.4810 Validation Accuracy: 0.705600
# Epoch  1, Batch 296 -Loss:  2485.6079 Validation Accuracy: 0.706000
# Epoch  1, Batch 297 -Loss:  1982.1917 Validation Accuracy: 0.708600
# Epoch  1, Batch 298 -Loss:  1628.8269 Validation Accuracy: 0.711000
# Epoch  1, Batch 299 -Loss:  2154.2300 Validation Accuracy: 0.710500
# Epoch  1, Batch 300 -Loss:  1748.2832 Validation Accuracy: 0.711400
# Epoch  1, Batch 301 -Loss:  2558.6089 Validation Accuracy: 0.713500
# Epoch  1, Batch 302 -Loss:  1529.7606 Validation Accuracy: 0.715500
# Epoch  1, Batch 303 -Loss:  2332.6135 Validation Accuracy: 0.714700
# Epoch  1, Batch 304 -Loss:  1691.5272 Validation Accuracy: 0.713300
# Epoch  1, Batch 305 -Loss:  2143.1982 Validation Accuracy: 0.712000
# Epoch  1, Batch 306 -Loss:  2057.1990 Validation Accuracy: 0.712200
# Epoch  1, Batch 307 -Loss:  1441.8545 Validation Accuracy: 0.714100
# Epoch  1, Batch 308 -Loss:  1906.4916 Validation Accuracy: 0.715300
# Epoch  1, Batch 309 -Loss:  3195.2793 Validation Accuracy: 0.715500
# Epoch  1, Batch 310 -Loss:  1893.1028 Validation Accuracy: 0.716300
# Epoch  1, Batch 311 -Loss:  1858.4738 Validation Accuracy: 0.717300
# Epoch  1, Batch 312 -Loss:  2375.4707 Validation Accuracy: 0.717300
# Epoch  1, Batch 313 -Loss:  2398.4028 Validation Accuracy: 0.719800
# Epoch  1, Batch 314 -Loss:  1831.0389 Validation Accuracy: 0.716500
# Epoch  1, Batch 315 -Loss:  1905.1946 Validation Accuracy: 0.718700
# Epoch  1, Batch 316 -Loss:  1859.5559 Validation Accuracy: 0.717000
# Epoch  1, Batch 317 -Loss:  1645.1993 Validation Accuracy: 0.717700
# Epoch  1, Batch 318 -Loss:  1904.9927 Validation Accuracy: 0.720200
# Epoch  1, Batch 319 -Loss:  2286.3867 Validation Accuracy: 0.720400
# Epoch  1, Batch 320 -Loss:  1420.0863 Validation Accuracy: 0.721100
# Epoch  1, Batch 321 -Loss:  1379.2736 Validation Accuracy: 0.721600
# Epoch  1, Batch 322 -Loss:  2254.1729 Validation Accuracy: 0.722400
# Epoch  1, Batch 323 -Loss:  1713.5968 Validation Accuracy: 0.722200
# Epoch  1, Batch 324 -Loss:  2647.7170 Validation Accuracy: 0.721700
# Epoch  1, Batch 325 -Loss:  3314.8315 Validation Accuracy: 0.722400
# Epoch  1, Batch 326 -Loss:  1959.6482 Validation Accuracy: 0.723100
# Epoch  1, Batch 327 -Loss:  2162.3699 Validation Accuracy: 0.723200
# Epoch  1, Batch 328 -Loss:  2237.4966 Validation Accuracy: 0.724300
# Epoch  1, Batch 329 -Loss:  2089.2439 Validation Accuracy: 0.724100
# Epoch  1, Batch 330 -Loss:  1671.8418 Validation Accuracy: 0.724700
# Epoch  1, Batch 331 -Loss:  2308.9285 Validation Accuracy: 0.724200
# Epoch  1, Batch 332 -Loss:  2926.4143 Validation Accuracy: 0.724100
# Epoch  1, Batch 333 -Loss:  2698.4854 Validation Accuracy: 0.725600
# Epoch  1, Batch 334 -Loss:  1322.4343 Validation Accuracy: 0.726600
# Epoch  1, Batch 335 -Loss:  1682.6501 Validation Accuracy: 0.726000
# Epoch  1, Batch 336 -Loss:  1263.3477 Validation Accuracy: 0.726500
# Epoch  1, Batch 337 -Loss:  2145.7551 Validation Accuracy: 0.726400
# Epoch  1, Batch 338 -Loss:  2716.9741 Validation Accuracy: 0.727800
# Epoch  1, Batch 339 -Loss:  1596.8949 Validation Accuracy: 0.726900
# Epoch  1, Batch 340 -Loss:   710.5615 Validation Accuracy: 0.728600
# Epoch  1, Batch 341 -Loss:  1420.4976 Validation Accuracy: 0.727300
# Epoch  1, Batch 342 -Loss:  1814.0719 Validation Accuracy: 0.728400
# Epoch  1, Batch 343 -Loss:  2178.2139 Validation Accuracy: 0.727600
# Epoch  1, Batch 344 -Loss:  1806.4496 Validation Accuracy: 0.726700
# Epoch  1, Batch 345 -Loss:  2115.5100 Validation Accuracy: 0.727400
# Epoch  1, Batch 346 -Loss:  1892.3374 Validation Accuracy: 0.728000
# Epoch  1, Batch 347 -Loss:  2105.6821 Validation Accuracy: 0.729700
# Epoch  1, Batch 348 -Loss:  1579.8088 Validation Accuracy: 0.730600
# Epoch  1, Batch 349 -Loss:  1624.3992 Validation Accuracy: 0.731300
# Epoch  1, Batch 350 -Loss:  1270.7780 Validation Accuracy: 0.732600
# Epoch  1, Batch 351 -Loss:  2518.9536 Validation Accuracy: 0.731700
# Epoch  1, Batch 352 -Loss:  1707.1060 Validation Accuracy: 0.730800
# Epoch  1, Batch 353 -Loss:  1880.6156 Validation Accuracy: 0.730100
# Epoch  1, Batch 354 -Loss:  1449.5685 Validation Accuracy: 0.726900
# Epoch  1, Batch 355 -Loss:  1616.4399 Validation Accuracy: 0.728500
# Epoch  1, Batch 356 -Loss:  1905.0834 Validation Accuracy: 0.732100
# Epoch  1, Batch 357 -Loss:  2029.5474 Validation Accuracy: 0.733200
# Epoch  1, Batch 358 -Loss:  1953.1221 Validation Accuracy: 0.733500
# Epoch  1, Batch 359 -Loss:  2050.2288 Validation Accuracy: 0.734700
# Epoch  1, Batch 360 -Loss:  1796.4926 Validation Accuracy: 0.734100
# Epoch  1, Batch 361 -Loss:  2153.5435 Validation Accuracy: 0.733600
# Epoch  1, Batch 362 -Loss:  2164.8921 Validation Accuracy: 0.734300
# Epoch  1, Batch 363 -Loss:  2479.6675 Validation Accuracy: 0.733900
# Epoch  1, Batch 364 -Loss:  2414.1619 Validation Accuracy: 0.734000
# Epoch  1, Batch 365 -Loss:  1519.8821 Validation Accuracy: 0.734200
# Epoch  1, Batch 366 -Loss:  2273.9839 Validation Accuracy: 0.733900
# Epoch  1, Batch 367 -Loss:  1622.6021 Validation Accuracy: 0.734700
# Epoch  1, Batch 368 -Loss:  1333.3579 Validation Accuracy: 0.734900
# Epoch  1, Batch 369 -Loss:  1665.7153 Validation Accuracy: 0.734800
# Epoch  1, Batch 370 -Loss:  1182.0464 Validation Accuracy: 0.734600
# Epoch  1, Batch 371 -Loss:  1693.7964 Validation Accuracy: 0.735400
# Epoch  1, Batch 372 -Loss:  1715.7574 Validation Accuracy: 0.736200
# Epoch  1, Batch 373 -Loss:  2543.2344 Validation Accuracy: 0.735800
# Epoch  1, Batch 374 -Loss:  1934.9949 Validation Accuracy: 0.736300
# Epoch  1, Batch 375 -Loss:  1162.3583 Validation Accuracy: 0.735000
# Epoch  1, Batch 376 -Loss:  1714.4141 Validation Accuracy: 0.735600
# Epoch  1, Batch 377 -Loss:  1256.1349 Validation Accuracy: 0.736900
# Epoch  1, Batch 378 -Loss:   938.0108 Validation Accuracy: 0.736300
# Epoch  1, Batch 379 -Loss:  1725.9319 Validation Accuracy: 0.737200
# Epoch  1, Batch 380 -Loss:  1598.4172 Validation Accuracy: 0.737100
# Epoch  1, Batch 381 -Loss:  1422.4720 Validation Accuracy: 0.737300
# Epoch  1, Batch 382 -Loss:  1537.3922 Validation Accuracy: 0.739500
# Epoch  1, Batch 383 -Loss:  1243.4526 Validation Accuracy: 0.739400
# Epoch  1, Batch 384 -Loss:  3146.1992 Validation Accuracy: 0.740400
# Epoch  1, Batch 385 -Loss:  2781.7053 Validation Accuracy: 0.740100
# Epoch  1, Batch 386 -Loss:  1644.7136 Validation Accuracy: 0.739900
# Epoch  1, Batch 387 -Loss:   872.6923 Validation Accuracy: 0.739900
# Epoch  1, Batch 388 -Loss:  1917.4923 Validation Accuracy: 0.740500
# Epoch  1, Batch 389 -Loss:  1564.1882 Validation Accuracy: 0.740800
# Epoch  1, Batch 390 -Loss:  1676.1753 Validation Accuracy: 0.741100
# Epoch  1, Batch 391 -Loss:  1904.9888 Validation Accuracy: 0.740700
# Epoch  1, Batch 392 -Loss:  1748.3252 Validation Accuracy: 0.742400
# Epoch  1, Batch 393 -Loss:  1193.3197 Validation Accuracy: 0.741700
# Epoch  1, Batch 394 -Loss:  1428.2865 Validation Accuracy: 0.740900
# Epoch  1, Batch 395 -Loss:  2980.1086 Validation Accuracy: 0.743000
# Epoch  1, Batch 396 -Loss:  1712.0798 Validation Accuracy: 0.744300
# Epoch  1, Batch 397 -Loss:  1820.3491 Validation Accuracy: 0.743500
# Epoch  1, Batch 398 -Loss:  1445.8586 Validation Accuracy: 0.743800
# Epoch  1, Batch 399 -Loss:  1375.0632 Validation Accuracy: 0.744000
# Epoch  1, Batch 400 -Loss:   893.8913 Validation Accuracy: 0.745200
# Epoch  1, Batch 401 -Loss:  1719.4917 Validation Accuracy: 0.745200
# Epoch  1, Batch 402 -Loss:  2181.0342 Validation Accuracy: 0.743000
# Epoch  1, Batch 403 -Loss:  1274.6978 Validation Accuracy: 0.744100
# Epoch  1, Batch 404 -Loss:  1647.3499 Validation Accuracy: 0.744200
# Epoch  1, Batch 405 -Loss:  1186.3301 Validation Accuracy: 0.744000
# Epoch  1, Batch 406 -Loss:  1498.4395 Validation Accuracy: 0.744600
# Epoch  1, Batch 407 -Loss:  1059.4664 Validation Accuracy: 0.745200
# Epoch  1, Batch 408 -Loss:  1719.7170 Validation Accuracy: 0.744100
# Epoch  1, Batch 409 -Loss:  2521.0278 Validation Accuracy: 0.745100
# Epoch  1, Batch 410 -Loss:  1360.9089 Validation Accuracy: 0.747100
# Epoch  1, Batch 411 -Loss:  1293.6766 Validation Accuracy: 0.746100
# Epoch  1, Batch 412 -Loss:   911.5747 Validation Accuracy: 0.746400
# Epoch  1, Batch 413 -Loss:  1454.7847 Validation Accuracy: 0.745300
# Epoch  1, Batch 414 -Loss:  1767.7969 Validation Accuracy: 0.745800
# Epoch  1, Batch 415 -Loss:  1733.5630 Validation Accuracy: 0.745400
# Epoch  1, Batch 416 -Loss:  2028.3331 Validation Accuracy: 0.747200
# Epoch  1, Batch 417 -Loss:  1572.3091 Validation Accuracy: 0.747200
# Epoch  1, Batch 418 -Loss:  1169.1394 Validation Accuracy: 0.746700
# Epoch  1, Batch 419 -Loss:  1074.7556 Validation Accuracy: 0.746200
# Epoch  1, Batch 420 -Loss:  1641.9534 Validation Accuracy: 0.746200
# Epoch  1, Batch 421 -Loss:  1661.7999 Validation Accuracy: 0.746700
# Epoch  1, Batch 422 -Loss:  1622.5045 Validation Accuracy: 0.748300
# Epoch  1, Batch 423 -Loss:  1805.1317 Validation Accuracy: 0.748800
# Epoch  1, Batch 424 -Loss:  1451.6375 Validation Accuracy: 0.748400
# Epoch  1, Batch 425 -Loss:   899.0239 Validation Accuracy: 0.748500
# Epoch  1, Batch 426 -Loss:  1212.2148 Validation Accuracy: 0.747600
# Epoch  1, Batch 427 -Loss:  1356.5000 Validation Accuracy: 0.747200
# Epoch  1, Batch 428 -Loss:  1219.3826 Validation Accuracy: 0.747400
# Epoch  1, Batch 429 -Loss:  1195.9351 Validation Accuracy: 0.746700
# Epoch  1, Batch 430 -Loss:  1134.9094 Validation Accuracy: 0.748100
# Epoch  1, Batch 431 -Loss:  1909.0482 Validation Accuracy: 0.749100
# Epoch  1, Batch 432 -Loss:  1127.5503 Validation Accuracy: 0.750200
# Epoch  1, Batch 433 -Loss:  1574.8456 Validation Accuracy: 0.750600
# Epoch  1, Batch 434 -Loss:   956.1862 Validation Accuracy: 0.749900
# Epoch  1, Batch 435 -Loss:  1129.4686 Validation Accuracy: 0.750300
# Epoch  1, Batch 436 -Loss:   991.2314 Validation Accuracy: 0.749500
# Epoch  1, Batch 437 -Loss:  1390.3428 Validation Accuracy: 0.747600
# Epoch  1, Batch 438 -Loss:  1459.0908 Validation Accuracy: 0.747800
# Epoch  1, Batch 439 -Loss:   758.8160 Validation Accuracy: 0.748900
# Epoch  1, Batch 440 -Loss:  1995.2700 Validation Accuracy: 0.750400
# Epoch  1, Batch 441 -Loss:  2304.9297 Validation Accuracy: 0.749400
# Epoch  1, Batch 442 -Loss:   599.6566 Validation Accuracy: 0.752000
# Epoch  1, Batch 443 -Loss:  1808.0345 Validation Accuracy: 0.751600
# Epoch  1, Batch 444 -Loss:  1214.7031 Validation Accuracy: 0.753200
# Epoch  1, Batch 445 -Loss:  1186.7427 Validation Accuracy: 0.753900
# Epoch  1, Batch 446 -Loss:  1210.3511 Validation Accuracy: 0.753000
# Epoch  1, Batch 447 -Loss:  1128.9473 Validation Accuracy: 0.753500
# Epoch  1, Batch 448 -Loss:  1034.8215 Validation Accuracy: 0.754700
# Epoch  1, Batch 449 -Loss:  1709.1907 Validation Accuracy: 0.756800
# Epoch  1, Batch 450 -Loss:   970.4695 Validation Accuracy: 0.754800
# Epoch  1, Batch 451 -Loss:  1049.5100 Validation Accuracy: 0.755500
# Epoch  1, Batch 452 -Loss:  1593.1763 Validation Accuracy: 0.755800
# Epoch  1, Batch 453 -Loss:  1498.4075 Validation Accuracy: 0.756400
# Epoch  1, Batch 454 -Loss:   914.8923 Validation Accuracy: 0.757200
# Epoch  1, Batch 455 -Loss:  1053.1995 Validation Accuracy: 0.757900
# Epoch  1, Batch 456 -Loss:   733.7533 Validation Accuracy: 0.757500
# Epoch  1, Batch 457 -Loss:   797.5897 Validation Accuracy: 0.757100
# Epoch  1, Batch 458 -Loss:  1388.9938 Validation Accuracy: 0.757100
# Epoch  1, Batch 459 -Loss:   678.0721 Validation Accuracy: 0.757800
# Epoch  1, Batch 460 -Loss:   969.5283 Validation Accuracy: 0.757900
# Epoch  1, Batch 461 -Loss:  1570.2723 Validation Accuracy: 0.758500
# Epoch  1, Batch 462 -Loss:   508.3533 Validation Accuracy: 0.758300
# Epoch  1, Batch 463 -Loss:   596.1207 Validation Accuracy: 0.758200
# Epoch  1, Batch 464 -Loss:  1007.1819 Validation Accuracy: 0.757900
# Epoch  1, Batch 465 -Loss:  2383.4199 Validation Accuracy: 0.758600
# Epoch  1, Batch 466 -Loss:  1925.0422 Validation Accuracy: 0.758400
# Epoch  1, Batch 467 -Loss:   839.8599 Validation Accuracy: 0.759200
# Epoch  1, Batch 468 -Loss:  1270.8282 Validation Accuracy: 0.759000
# Epoch  1, Batch 469 -Loss:   615.5529 Validation Accuracy: 0.759200
# Epoch  1, Batch 470 -Loss:  1399.6659 Validation Accuracy: 0.759500
# Epoch  2, Batch   2 -Loss:  1110.0100 Validation Accuracy: 0.759900
# Epoch  2, Batch   3 -Loss:  1419.2117 Validation Accuracy: 0.760100
# Epoch  2, Batch   4 -Loss:   615.1442 Validation Accuracy: 0.761300
# Epoch  2, Batch   5 -Loss:  1398.0918 Validation Accuracy: 0.760900
# Epoch  2, Batch   6 -Loss:  1575.4010 Validation Accuracy: 0.761400
# Epoch  2, Batch   7 -Loss:  1447.3684 Validation Accuracy: 0.761200
# Epoch  2, Batch   8 -Loss:  1444.3892 Validation Accuracy: 0.762000
# Epoch  2, Batch   9 -Loss:  1962.7947 Validation Accuracy: 0.762000
# Epoch  2, Batch  10 -Loss:  1901.9675 Validation Accuracy: 0.761800
# Epoch  2, Batch  11 -Loss:   893.5355 Validation Accuracy: 0.760400
# Epoch  2, Batch  12 -Loss:  1410.3369 Validation Accuracy: 0.760100
# Epoch  2, Batch  13 -Loss:   927.7966 Validation Accuracy: 0.757700
# Epoch  2, Batch  14 -Loss:   863.0637 Validation Accuracy: 0.759300
# Epoch  2, Batch  15 -Loss:   957.3829 Validation Accuracy: 0.760400
# Epoch  2, Batch  16 -Loss:  1073.7423 Validation Accuracy: 0.759700
# Epoch  2, Batch  17 -Loss:  1069.6215 Validation Accuracy: 0.759700
# Epoch  2, Batch  18 -Loss:   979.9116 Validation Accuracy: 0.760200
# Epoch  2, Batch  19 -Loss:   985.2723 Validation Accuracy: 0.761000
# Epoch  2, Batch  20 -Loss:  1646.6008 Validation Accuracy: 0.761600
# Epoch  2, Batch  21 -Loss:  1239.9003 Validation Accuracy: 0.762100
# Epoch  2, Batch  22 -Loss:  1764.1228 Validation Accuracy: 0.763300
# Epoch  2, Batch  23 -Loss:  1833.2880 Validation Accuracy: 0.761800
# Epoch  2, Batch  24 -Loss:  1429.8297 Validation Accuracy: 0.762400
# Epoch  2, Batch  25 -Loss:  1672.9050 Validation Accuracy: 0.763000
# Epoch  2, Batch  26 -Loss:   956.3090 Validation Accuracy: 0.764400
# Epoch  2, Batch  27 -Loss:   935.5555 Validation Accuracy: 0.764000
# Epoch  2, Batch  28 -Loss:   891.4410 Validation Accuracy: 0.764600
# Epoch  2, Batch  29 -Loss:  1223.4983 Validation Accuracy: 0.765400
# Epoch  2, Batch  30 -Loss:  1040.2012 Validation Accuracy: 0.765700
# Epoch  2, Batch  31 -Loss:  1418.8792 Validation Accuracy: 0.766200
# Epoch  2, Batch  32 -Loss:  1179.0759 Validation Accuracy: 0.766800
# Epoch  2, Batch  33 -Loss:  1891.4580 Validation Accuracy: 0.765700
# Epoch  2, Batch  34 -Loss:  1212.4939 Validation Accuracy: 0.765400
# Epoch  2, Batch  35 -Loss:  1249.6582 Validation Accuracy: 0.766300
# Epoch  2, Batch  36 -Loss:  1289.1379 Validation Accuracy: 0.766800
# Epoch  2, Batch  37 -Loss:   935.9415 Validation Accuracy: 0.767000
# Epoch  2, Batch  38 -Loss:  1355.6565 Validation Accuracy: 0.766900
# Epoch  2, Batch  39 -Loss:  1969.2708 Validation Accuracy: 0.766600
# Epoch  2, Batch  40 -Loss:  1521.0717 Validation Accuracy: 0.766100
# Epoch  2, Batch  41 -Loss:  1055.8287 Validation Accuracy: 0.765600
# Epoch  2, Batch  42 -Loss:  1560.4194 Validation Accuracy: 0.766200
# Epoch  2, Batch  43 -Loss:   778.4323 Validation Accuracy: 0.766200
# Epoch  2, Batch  44 -Loss:   953.4020 Validation Accuracy: 0.766100
# Epoch  2, Batch  45 -Loss:   911.5435 Validation Accuracy: 0.766300
# Epoch  2, Batch  46 -Loss:  1328.3032 Validation Accuracy: 0.766800
# Epoch  2, Batch  47 -Loss:  1437.5359 Validation Accuracy: 0.768100
# Epoch  2, Batch  48 -Loss:  1164.7997 Validation Accuracy: 0.768000
# Epoch  2, Batch  49 -Loss:  1107.3831 Validation Accuracy: 0.767100
# Epoch  2, Batch  50 -Loss:   987.5131 Validation Accuracy: 0.765300
# Epoch  2, Batch  51 -Loss:   932.8264 Validation Accuracy: 0.764300
# Epoch  2, Batch  52 -Loss:  1251.2946 Validation Accuracy: 0.765500
# Epoch  2, Batch  53 -Loss:  1031.4882 Validation Accuracy: 0.767100
# Epoch  2, Batch  54 -Loss:  1188.5664 Validation Accuracy: 0.768800
# Epoch  2, Batch  55 -Loss:  1878.2284 Validation Accuracy: 0.768200
# Epoch  2, Batch  56 -Loss:  1216.9633 Validation Accuracy: 0.769300
# Epoch  2, Batch  57 -Loss:   825.5900 Validation Accuracy: 0.769200
# Epoch  2, Batch  58 -Loss:  2345.0574 Validation Accuracy: 0.769800
# Epoch  2, Batch  59 -Loss:  1370.9797 Validation Accuracy: 0.771200
# Epoch  2, Batch  60 -Loss:  1266.5696 Validation Accuracy: 0.771600
# Epoch  2, Batch  61 -Loss:   940.9880 Validation Accuracy: 0.771900
# Epoch  2, Batch  62 -Loss:  1593.6165 Validation Accuracy: 0.770900
# Epoch  2, Batch  63 -Loss:  1911.0186 Validation Accuracy: 0.772400
# Epoch  2, Batch  64 -Loss:   978.3502 Validation Accuracy: 0.772700
# Epoch  2, Batch  65 -Loss:  1237.5183 Validation Accuracy: 0.772400
# Epoch  2, Batch  66 -Loss:  1920.3186 Validation Accuracy: 0.772300
# Epoch  2, Batch  67 -Loss:  1074.1234 Validation Accuracy: 0.773000
# Epoch  2, Batch  68 -Loss:   921.3631 Validation Accuracy: 0.774900
# Epoch  2, Batch  69 -Loss:  1657.3359 Validation Accuracy: 0.773800
# Epoch  2, Batch  70 -Loss:  1914.6150 Validation Accuracy: 0.774700
# Epoch  2, Batch  71 -Loss:  1581.1262 Validation Accuracy: 0.775000
# Epoch  2, Batch  72 -Loss:   637.4857 Validation Accuracy: 0.775000
# Epoch  2, Batch  73 -Loss:   829.1677 Validation Accuracy: 0.774400
# Epoch  2, Batch  74 -Loss:  1276.0967 Validation Accuracy: 0.775500
# Epoch  2, Batch  75 -Loss:  1436.0291 Validation Accuracy: 0.774800
# Epoch  2, Batch  76 -Loss:  1135.3386 Validation Accuracy: 0.774500
# Epoch  2, Batch  77 -Loss:  1466.1567 Validation Accuracy: 0.774700
# Epoch  2, Batch  78 -Loss:  1308.1454 Validation Accuracy: 0.775400
# Epoch  2, Batch  79 -Loss:   816.9294 Validation Accuracy: 0.774100
# Epoch  2, Batch  80 -Loss:  1022.2883 Validation Accuracy: 0.775300
# Epoch  2, Batch  81 -Loss:  1623.6246 Validation Accuracy: 0.775300
# Epoch  2, Batch  82 -Loss:  1432.4498 Validation Accuracy: 0.775400
# Epoch  2, Batch  83 -Loss:   832.1972 Validation Accuracy: 0.774900
# Epoch  2, Batch  84 -Loss:   696.3281 Validation Accuracy: 0.776100
# Epoch  2, Batch  85 -Loss:   907.7408 Validation Accuracy: 0.776500
# Epoch  2, Batch  86 -Loss:  1432.4255 Validation Accuracy: 0.776600
# Epoch  2, Batch  87 -Loss:  1227.3271 Validation Accuracy: 0.776700
# Epoch  2, Batch  88 -Loss:   977.5110 Validation Accuracy: 0.774200
# Epoch  2, Batch  89 -Loss:  1289.1582 Validation Accuracy: 0.774700
# Epoch  2, Batch  90 -Loss:   997.8193 Validation Accuracy: 0.777100
# Epoch  2, Batch  91 -Loss:   920.2031 Validation Accuracy: 0.777000
# Epoch  2, Batch  92 -Loss:  1201.4099 Validation Accuracy: 0.776100
# Epoch  2, Batch  93 -Loss:  1721.9678 Validation Accuracy: 0.776400
# Epoch  2, Batch  94 -Loss:   941.4218 Validation Accuracy: 0.775900
# Epoch  2, Batch  95 -Loss:   989.1908 Validation Accuracy: 0.774700
# Epoch  2, Batch  96 -Loss:   761.2260 Validation Accuracy: 0.773500
# Epoch  2, Batch  97 -Loss:  1143.2444 Validation Accuracy: 0.775400
# Epoch  2, Batch  98 -Loss:   882.9548 Validation Accuracy: 0.774200
# Epoch  2, Batch  99 -Loss:  1534.6908 Validation Accuracy: 0.777300
# Epoch  2, Batch 100 -Loss:  1932.7477 Validation Accuracy: 0.776600
# Epoch  2, Batch 101 -Loss:  1109.1670 Validation Accuracy: 0.778000
# Epoch  2, Batch 102 -Loss:   951.0466 Validation Accuracy: 0.778200
# Epoch  2, Batch 103 -Loss:  1600.8120 Validation Accuracy: 0.778300
# Epoch  2, Batch 104 -Loss:  1510.7520 Validation Accuracy: 0.777100
# Epoch  2, Batch 105 -Loss:  1148.2166 Validation Accuracy: 0.774600
# Epoch  2, Batch 106 -Loss:   783.8230 Validation Accuracy: 0.778300
# Epoch  2, Batch 107 -Loss:  1087.6263 Validation Accuracy: 0.778200
# Epoch  2, Batch 108 -Loss:  1189.8098 Validation Accuracy: 0.778000
# Epoch  2, Batch 109 -Loss:  1638.3716 Validation Accuracy: 0.776700
# Epoch  2, Batch 110 -Loss:  1498.8141 Validation Accuracy: 0.778800
# Epoch  2, Batch 111 -Loss:  1491.9698 Validation Accuracy: 0.778200
# Epoch  2, Batch 112 -Loss:  1434.6833 Validation Accuracy: 0.778300
# Epoch  2, Batch 113 -Loss:  2027.7510 Validation Accuracy: 0.778900
# Epoch  2, Batch 114 -Loss:  1520.1913 Validation Accuracy: 0.777800
# Epoch  2, Batch 115 -Loss:  1737.8608 Validation Accuracy: 0.779100
# Epoch  2, Batch 116 -Loss:  1803.5560 Validation Accuracy: 0.780600
# Epoch  2, Batch 117 -Loss:  2187.5649 Validation Accuracy: 0.780900
# Epoch  2, Batch 118 -Loss:  1043.9927 Validation Accuracy: 0.779700
# Epoch  2, Batch 119 -Loss:   963.1389 Validation Accuracy: 0.779700
# Epoch  2, Batch 120 -Loss:  1477.1268 Validation Accuracy: 0.780000
# Epoch  2, Batch 121 -Loss:  1104.6987 Validation Accuracy: 0.779500
# Epoch  2, Batch 122 -Loss:  1227.6489 Validation Accuracy: 0.779700
# Epoch  2, Batch 123 -Loss:  1107.7750 Validation Accuracy: 0.780100
# Epoch  2, Batch 124 -Loss:  1436.2034 Validation Accuracy: 0.780200
# Epoch  2, Batch 125 -Loss:  1743.1787 Validation Accuracy: 0.779100
# Epoch  2, Batch 126 -Loss:  1240.7578 Validation Accuracy: 0.780000
# Epoch  2, Batch 127 -Loss:  1386.1371 Validation Accuracy: 0.779200
# Epoch  2, Batch 128 -Loss:  1102.0769 Validation Accuracy: 0.778300
# Epoch  2, Batch 129 -Loss:   862.9921 Validation Accuracy: 0.779100
# Epoch  2, Batch 130 -Loss:  1219.5698 Validation Accuracy: 0.778900
# Epoch  2, Batch 131 -Loss:   819.2471 Validation Accuracy: 0.778800
# Epoch  2, Batch 132 -Loss:  1421.5970 Validation Accuracy: 0.779800
# Epoch  2, Batch 133 -Loss:  1617.1274 Validation Accuracy: 0.778500
# Epoch  2, Batch 134 -Loss:  1328.5466 Validation Accuracy: 0.779200
# Epoch  2, Batch 135 -Loss:  1420.4089 Validation Accuracy: 0.778800
# Epoch  2, Batch 136 -Loss:  1715.9089 Validation Accuracy: 0.780100
# Epoch  2, Batch 137 -Loss:   614.9862 Validation Accuracy: 0.779600
# Epoch  2, Batch 138 -Loss:  1154.6858 Validation Accuracy: 0.778400
# Epoch  2, Batch 139 -Loss:  1481.2886 Validation Accuracy: 0.778800
# Epoch  2, Batch 140 -Loss:  1487.8130 Validation Accuracy: 0.779800
# Epoch  2, Batch 141 -Loss:  1342.9077 Validation Accuracy: 0.779300
# Epoch  2, Batch 142 -Loss:   689.4386 Validation Accuracy: 0.780100
# Epoch  2, Batch 143 -Loss:   971.9270 Validation Accuracy: 0.781100
# Epoch  2, Batch 144 -Loss:   976.0653 Validation Accuracy: 0.781300
# Epoch  2, Batch 145 -Loss:  1028.2435 Validation Accuracy: 0.781300
# Epoch  2, Batch 146 -Loss:   906.8043 Validation Accuracy: 0.781100
# Epoch  2, Batch 147 -Loss:   806.2598 Validation Accuracy: 0.781700
# Epoch  2, Batch 148 -Loss:   960.6736 Validation Accuracy: 0.782700
# Epoch  2, Batch 149 -Loss:   584.4241 Validation Accuracy: 0.782400
# Epoch  2, Batch 150 -Loss:  1085.9727 Validation Accuracy: 0.783200
# Epoch  2, Batch 151 -Loss:  1379.3580 Validation Accuracy: 0.783100
# Epoch  2, Batch 152 -Loss:   881.2206 Validation Accuracy: 0.783200
# Epoch  2, Batch 153 -Loss:   919.3549 Validation Accuracy: 0.784000
# Epoch  2, Batch 154 -Loss:  1114.3706 Validation Accuracy: 0.783900
# Epoch  2, Batch 155 -Loss:   893.4553 Validation Accuracy: 0.782300
# Epoch  2, Batch 156 -Loss:  1535.6974 Validation Accuracy: 0.782600
# Epoch  2, Batch 157 -Loss:  1453.4226 Validation Accuracy: 0.782600
# Epoch  2, Batch 158 -Loss:  1408.9661 Validation Accuracy: 0.782600
# Epoch  2, Batch 159 -Loss:  1532.5394 Validation Accuracy: 0.780800
# Epoch  2, Batch 160 -Loss:  1034.5302 Validation Accuracy: 0.781900
# Epoch  2, Batch 161 -Loss:  1148.9248 Validation Accuracy: 0.782900
# Epoch  2, Batch 162 -Loss:  1255.9425 Validation Accuracy: 0.784100
# Epoch  2, Batch 163 -Loss:  1208.6757 Validation Accuracy: 0.784900
# Epoch  2, Batch 164 -Loss:  1151.1698 Validation Accuracy: 0.782900
# Epoch  2, Batch 165 -Loss:  1162.6998 Validation Accuracy: 0.784100
# Epoch  2, Batch 166 -Loss:  1103.2053 Validation Accuracy: 0.784600
# Epoch  2, Batch 167 -Loss:   875.8389 Validation Accuracy: 0.784700
# Epoch  2, Batch 168 -Loss:   993.2834 Validation Accuracy: 0.784800
# Epoch  2, Batch 169 -Loss:  1081.5189 Validation Accuracy: 0.784700
# Epoch  2, Batch 170 -Loss:   992.8296 Validation Accuracy: 0.784300
# Epoch  2, Batch 171 -Loss:  1183.4668 Validation Accuracy: 0.784400
# Epoch  2, Batch 172 -Loss:   724.3414 Validation Accuracy: 0.785100
# Epoch  2, Batch 173 -Loss:   679.5997 Validation Accuracy: 0.784900
# Epoch  2, Batch 174 -Loss:  1497.3679 Validation Accuracy: 0.784200
# Epoch  2, Batch 175 -Loss:  1883.1909 Validation Accuracy: 0.785800
# Epoch  2, Batch 176 -Loss:   971.5320 Validation Accuracy: 0.784400
# Epoch  2, Batch 177 -Loss:  1451.9031 Validation Accuracy: 0.786300
# Epoch  2, Batch 178 -Loss:  1906.2740 Validation Accuracy: 0.785300
# Epoch  2, Batch 179 -Loss:  1214.0044 Validation Accuracy: 0.782900
# Epoch  2, Batch 180 -Loss:  1347.1660 Validation Accuracy: 0.783400
# Epoch  2, Batch 181 -Loss:   778.2607 Validation Accuracy: 0.783500
# Epoch  2, Batch 182 -Loss:   939.9282 Validation Accuracy: 0.785800
# Epoch  2, Batch 183 -Loss:   785.1526 Validation Accuracy: 0.785600
# Epoch  2, Batch 184 -Loss:   902.5217 Validation Accuracy: 0.786300
# Epoch  2, Batch 185 -Loss:   923.9475 Validation Accuracy: 0.786200
# Epoch  2, Batch 186 -Loss:   843.8341 Validation Accuracy: 0.786000
# Epoch  2, Batch 187 -Loss:  1038.3348 Validation Accuracy: 0.787100
# Epoch  2, Batch 188 -Loss:  1013.4589 Validation Accuracy: 0.787000
# Epoch  2, Batch 189 -Loss:  1076.5808 Validation Accuracy: 0.786700
# Epoch  2, Batch 190 -Loss:   736.2225 Validation Accuracy: 0.787800
# Epoch  2, Batch 191 -Loss:  1712.3430 Validation Accuracy: 0.786200
# Epoch  2, Batch 192 -Loss:   885.2976 Validation Accuracy: 0.786200
# Epoch  2, Batch 193 -Loss:  1437.2556 Validation Accuracy: 0.787500
# Epoch  2, Batch 194 -Loss:  1683.3207 Validation Accuracy: 0.788200
# Epoch  2, Batch 195 -Loss:  1812.2449 Validation Accuracy: 0.788100
# Epoch  2, Batch 196 -Loss:   996.9199 Validation Accuracy: 0.788300
# Epoch  2, Batch 197 -Loss:   606.6104 Validation Accuracy: 0.787500
# Epoch  2, Batch 198 -Loss:   876.0026 Validation Accuracy: 0.788300
# Epoch  2, Batch 199 -Loss:  1365.0055 Validation Accuracy: 0.788600
# Epoch  2, Batch 200 -Loss:   803.2700 Validation Accuracy: 0.788500
# Epoch  2, Batch 201 -Loss:   601.3114 Validation Accuracy: 0.788100
# Epoch  2, Batch 202 -Loss:  1240.8604 Validation Accuracy: 0.790000
# Epoch  2, Batch 203 -Loss:   962.6298 Validation Accuracy: 0.790400
# Epoch  2, Batch 204 -Loss:  1242.9578 Validation Accuracy: 0.790000
# Epoch  2, Batch 205 -Loss:  1147.1525 Validation Accuracy: 0.788800
# Epoch  2, Batch 206 -Loss:  1097.2454 Validation Accuracy: 0.789200
# Epoch  2, Batch 207 -Loss:   594.1948 Validation Accuracy: 0.791000
# Epoch  2, Batch 208 -Loss:   987.8691 Validation Accuracy: 0.790700
# Epoch  2, Batch 209 -Loss:  1521.3097 Validation Accuracy: 0.790300
# Epoch  2, Batch 210 -Loss:  1682.3784 Validation Accuracy: 0.791000
# Epoch  2, Batch 211 -Loss:  1375.9358 Validation Accuracy: 0.790800
# Epoch  2, Batch 212 -Loss:   843.2636 Validation Accuracy: 0.789900
# Epoch  2, Batch 213 -Loss:   905.5952 Validation Accuracy: 0.790700
# Epoch  2, Batch 214 -Loss:  1041.0206 Validation Accuracy: 0.790700
# Epoch  2, Batch 215 -Loss:   763.6907 Validation Accuracy: 0.790900
# Epoch  2, Batch 216 -Loss:  1549.1188 Validation Accuracy: 0.791400
# Epoch  2, Batch 217 -Loss:   782.9403 Validation Accuracy: 0.791000
# Epoch  2, Batch 218 -Loss:   924.9587 Validation Accuracy: 0.792000
# Epoch  2, Batch 219 -Loss:  1155.3501 Validation Accuracy: 0.793100
# Epoch  2, Batch 220 -Loss:   802.5897 Validation Accuracy: 0.793200
# Epoch  2, Batch 221 -Loss:   725.9988 Validation Accuracy: 0.792600
# Epoch  2, Batch 222 -Loss:  1101.4985 Validation Accuracy: 0.793700
# Epoch  2, Batch 223 -Loss:  1063.1775 Validation Accuracy: 0.792900
# Epoch  2, Batch 224 -Loss:  1279.2881 Validation Accuracy: 0.792100
# Epoch  2, Batch 225 -Loss:  1516.5881 Validation Accuracy: 0.792200
# Epoch  2, Batch 226 -Loss:   955.3724 Validation Accuracy: 0.793700
# Epoch  2, Batch 227 -Loss:  1321.9583 Validation Accuracy: 0.794600
# Epoch  2, Batch 228 -Loss:   896.9943 Validation Accuracy: 0.795200
# Epoch  2, Batch 229 -Loss:  1322.7188 Validation Accuracy: 0.794300
# Epoch  2, Batch 230 -Loss:  1115.6080 Validation Accuracy: 0.794300
# Epoch  2, Batch 231 -Loss:  1227.7516 Validation Accuracy: 0.795700
# Epoch  2, Batch 232 -Loss:   910.1755 Validation Accuracy: 0.795000
# Epoch  2, Batch 233 -Loss:   928.9651 Validation Accuracy: 0.796100
# Epoch  2, Batch 234 -Loss:  1488.6141 Validation Accuracy: 0.794400
# Epoch  2, Batch 235 -Loss:  1473.2461 Validation Accuracy: 0.795700
# Epoch  2, Batch 236 -Loss:  1145.8022 Validation Accuracy: 0.796100
# Epoch  2, Batch 237 -Loss:  1451.2756 Validation Accuracy: 0.794900
# Epoch  2, Batch 238 -Loss:   874.4642 Validation Accuracy: 0.794900
# Epoch  2, Batch 239 -Loss:  1082.6949 Validation Accuracy: 0.795400
# Epoch  2, Batch 240 -Loss:  1020.3234 Validation Accuracy: 0.796100
# Epoch  2, Batch 241 -Loss:  1018.1932 Validation Accuracy: 0.796900
# Epoch  2, Batch 242 -Loss:  1290.5848 Validation Accuracy: 0.797700
# Epoch  2, Batch 243 -Loss:  1432.1792 Validation Accuracy: 0.797200
# Epoch  2, Batch 244 -Loss:  1650.3831 Validation Accuracy: 0.797300
# Epoch  2, Batch 245 -Loss:  1280.1272 Validation Accuracy: 0.797600
# Epoch  2, Batch 246 -Loss:  1736.2065 Validation Accuracy: 0.796600
# Epoch  2, Batch 247 -Loss:   789.3407 Validation Accuracy: 0.797300
# Epoch  2, Batch 248 -Loss:   890.7477 Validation Accuracy: 0.796000
# Epoch  2, Batch 249 -Loss:  1483.7788 Validation Accuracy: 0.796900
# Epoch  2, Batch 250 -Loss:  1225.8508 Validation Accuracy: 0.797100
# Epoch  2, Batch 251 -Loss:  1044.0736 Validation Accuracy: 0.797400
# Epoch  2, Batch 252 -Loss:  1288.4567 Validation Accuracy: 0.796700
# Epoch  2, Batch 253 -Loss:  1210.0436 Validation Accuracy: 0.797100
# Epoch  2, Batch 254 -Loss:  1497.8590 Validation Accuracy: 0.798000
# Epoch  2, Batch 255 -Loss:  1607.6404 Validation Accuracy: 0.796300
# Epoch  2, Batch 256 -Loss:   688.1973 Validation Accuracy: 0.796000
# Epoch  2, Batch 257 -Loss:   830.5796 Validation Accuracy: 0.796600
# Epoch  2, Batch 258 -Loss:  1198.3159 Validation Accuracy: 0.796100
# Epoch  2, Batch 259 -Loss:  1098.6943 Validation Accuracy: 0.796100
# Epoch  2, Batch 260 -Loss:  1349.4838 Validation Accuracy: 0.796900
# Epoch  2, Batch 261 -Loss:  1416.3912 Validation Accuracy: 0.797300
# Epoch  2, Batch 262 -Loss:   826.2311 Validation Accuracy: 0.797000
# Epoch  2, Batch 263 -Loss:  1083.8455 Validation Accuracy: 0.796900
# Epoch  2, Batch 264 -Loss:  1035.1787 Validation Accuracy: 0.796600
# Epoch  2, Batch 265 -Loss:  1001.8348 Validation Accuracy: 0.797700
# Epoch  2, Batch 266 -Loss:   603.6584 Validation Accuracy: 0.797700
# Epoch  2, Batch 267 -Loss:   402.2858 Validation Accuracy: 0.796700
# Epoch  2, Batch 268 -Loss:   903.7733 Validation Accuracy: 0.796700
# Epoch  2, Batch 269 -Loss:   575.9049 Validation Accuracy: 0.797000
# Epoch  2, Batch 270 -Loss:  1189.6680 Validation Accuracy: 0.797000
# Epoch  2, Batch 271 -Loss:  1244.2048 Validation Accuracy: 0.798200
# Epoch  2, Batch 272 -Loss:  1229.1459 Validation Accuracy: 0.797400
# Epoch  2, Batch 273 -Loss:  1054.6533 Validation Accuracy: 0.797900
# Epoch  2, Batch 274 -Loss:  1102.3889 Validation Accuracy: 0.799000
# Epoch  2, Batch 275 -Loss:   574.4733 Validation Accuracy: 0.798300
# Epoch  2, Batch 276 -Loss:  1040.4392 Validation Accuracy: 0.798200
# Epoch  2, Batch 277 -Loss:  1053.4023 Validation Accuracy: 0.799300
# Epoch  2, Batch 278 -Loss:   894.5533 Validation Accuracy: 0.798800
# Epoch  2, Batch 279 -Loss:   588.1538 Validation Accuracy: 0.799100
# Epoch  2, Batch 280 -Loss:   859.3995 Validation Accuracy: 0.799800
# Epoch  2, Batch 281 -Loss:   649.3795 Validation Accuracy: 0.800700
# Epoch  2, Batch 282 -Loss:  1242.1621 Validation Accuracy: 0.799300
# Epoch  2, Batch 283 -Loss:  1458.2202 Validation Accuracy: 0.799900
# Epoch  2, Batch 284 -Loss:   723.3840 Validation Accuracy: 0.800300
# Epoch  2, Batch 285 -Loss:   625.8191 Validation Accuracy: 0.798600
# Epoch  2, Batch 286 -Loss:  1413.9905 Validation Accuracy: 0.798700
# Epoch  2, Batch 287 -Loss:   909.7314 Validation Accuracy: 0.798300
# Epoch  2, Batch 288 -Loss:   528.1066 Validation Accuracy: 0.798200
# Epoch  2, Batch 289 -Loss:  1543.1007 Validation Accuracy: 0.799800
# Epoch  2, Batch 290 -Loss:   841.7037 Validation Accuracy: 0.798700
# Epoch  2, Batch 291 -Loss:  1280.5469 Validation Accuracy: 0.797100
# Epoch  2, Batch 292 -Loss:  1098.4753 Validation Accuracy: 0.797200
# Epoch  2, Batch 293 -Loss:  1726.6528 Validation Accuracy: 0.795200
